# %% [markdown]
# ##### by Anastasiia Khaburska
#
# ## Homework 5
#
# module : **Deep Learning for NLP**
#
#
# The goal of the homework is to develop a tool for Named Entity Recognition. You need to implement model **”Glove word embeddings + BiLSTM + Softmax”** for sequence labeling. Please, use the standard PyTorch example for the sequence labeling task ”Sequence models and long-short term memory networks”(https://pytorch.org/tutorials/beginner/nlp/sequence_models_tutorial.html#sphx-glr-beginner-nlp-sequence-models-tutorial-py) as a basic code to start. Glove word embeddings can be downloaded here (http://neuroner.com/data/word_vectors/glove.6B.100d.zip).

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

torch.manual_seed(1)

import pandas as pd
import numpy as np
import gensim
import pickle
import os
import pandas as pd

# %% [markdown]
# ### **Task 1**:
# Implement functionality to read and process NER 2003 English Shared Task data in CoNNL file format, data will be provided (10% of score).

# %%
def process(filename):
    with open(f'data/{filename}.txt') as file:
        size = 0
        for line in file:
            if line != '\n':
                w, _, _, _ = line.split(' ')
                if (w!='-DOCSTART-'):
                    size+=1
    
    df = pd.DataFrame(
            columns=['sentence', 'word', 'POS_tag', 'SCHUNK_tag', 'NE_tag'],
            data=np.zeros((size, 5))
        )
    df[:] = ''
    with open(f'data/{filename}.txt') as file:
        index = 0
        word = 0
        for line in file:
            if line == '\n':
                index += 1
            else:
                w, p, s, n = line.split(' ')
                if (w!='-DOCSTART-'):
                    df.at[word, 'sentence'] = int(index)
                    df.at[word, 'word'] = w.strip()
                    df.at[word, 'POS_tag'] = p.strip()
                    df.at[word, 'SCHUNK_tag'] = s.strip()               
                    df.at[word, 'NE_tag'] = n.strip()
                    word += 1
        return df

# %%
train = process('train')
dev = process('dev')
test = process('test')

# %%
print(f"Length of train: {len(train)}")
print(f"Length of  dev:   {len(dev)}")
print(f"Length of  test:  {len(test)}")
# Out:
# Length of train: 203621
# Length of  dev:   51362
# Length of  test:  46435

# %%
print(f"Number of sentences in train: {len(train['sentence'].unique())}")
print(f"Number of sentences in dev:   {len(dev['sentence'].unique())}")
print(f"Number of sentences in test:  {len(test['sentence'].unique())}")
# Out:
# Number of sentences in train: 14041
# Number of sentences in dev:   3250
# Number of sentences in test:  3453

# %%
print("Named entity tags:",sorted(train['NE_tag'].unique()))
# Out:
# Named entity tags: ['B-LOC', 'B-MISC', 'B-ORG', 'B-PER', 'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O']

# %% [markdown]
# **Prepare data:**

# %%
def prepare_sequence(seq, to_ix):
    
    idxs = [to_ix[w] for w in seq]
    
    return torch.tensor(idxs, dtype=torch.long)

# %%
tag_to_ix = {'B-LOC':0, 'B-MISC':1, 'B-ORG':2, 'B-PER':3, 'I-LOC':4, 'I-MISC':5, 'I-ORG':6, 'I-PER':7, 'O':8}

# %%
word_to_ix = {}

for word in train['word']:
    if word not in word_to_ix:
        word_to_ix[word] = len(word_to_ix)
for word in dev['word']:
    if word not in word_to_ix:
        word_to_ix[word] = len(word_to_ix)
for word in test['word']:
    if word not in word_to_ix:
        word_to_ix[word] = len(word_to_ix)

# %%
print(word_to_ix)
# Out:
# {'EU': 0, 'rejects': 1, 'German': 2, 'call': 3, 'to': 4, 'boycott': 5, 'British': 6, 'lamb': 7, '.': 8, 'Peter': 9, 'Blackburn': 10, 'BRUSSELS': 11, '1996-08-22': 12, 'The': 13, 'European': 14, 'Commission': 15, 'said': 16, 'on': 17, 'Thursday': 18, 'it': 19, 'disagreed': 20, 'with': 21, 'advice': 22, 'consumers': 23, 'shun': 24, 'until': 25, 'scientists': 26, 'determine': 27, 'whether': 28, 'mad': 29, 'cow': 30, 'disease': 31, 'can': 32, 'be': 33, 'transmitted': 34, 'sheep': 35, 'Germany': 36, "'s": 37, 'representative': 38, 'the': 39, 'Union': 40, 'veterinary': 41, 'committee': 42, 'Werner': 43, 'Zwingmann': 44, 'Wednesday': 45, 'should': 46, 'buy': 47, 'sheepmeat': 48, 'from': 49, 'countries': 50, 'other': 51, 'than': 52, 'Britain': 53, 'scientific': 54, 'was': 55, 'clearer': 56, '"': 57, 'We': 58, 'do': 59, "n't": 60, 'support': 61, 'any': 62, 'such': 63, 'recommendation': 64, 'because': 65, 'we': 66, 'see': 67, 'grounds': 68, 'for': 69, ',': 70, 'chief': 71, 'spokesman': 72, 'Nikolaus': 73, 'van': 74, 'der': 75, 'Pas': 76, 'told': 77, 'a': 78, 'news': 79, 'briefing': 80, 'He': 81, 'further': 82, 'study': 83, 'required': 84, 'and': 85, 'if': 86, 'found': 87, 'that': 88, 'action': 89, 'needed': 90, 'taken': 91, 'by': 92, 'proposal': 93, 'last': 94, 'month': 95, 'Farm': 96, 'Commissioner': 97, 'Franz': 98, 'Fischler': 99, 'ban': 100, 'brains': 101, 'spleens': 102, 'spinal': 103, 'cords': 104, 'human': 105, 'animal': 106, 'food': 107, 'chains': 108, 'highly': 109, 'specific': 110, 'precautionary': 111, 'move': 112, 'protect': 113, 'health': 114, 'proposed': 115, 'EU-wide': 116, 'measures': 117, 'after': 118, 'reports': 119, 'France': 120, 'under': 121, 'laboratory': 122, 'conditions': 123, 'could': 124, 'contract': 125, 'Bovine': 126, 'Spongiform': 127, 'Encephalopathy': 128, '(': 129, 'BSE': 130, ')': 131, '--': 132, 'But': 133, 'agreed': 134, 'review': 135, 'his': 136, 'standing': 137, 'mational': 138, 'officials': 139, 'questioned': 140, 'justified': 141, 'as': 142, 'there': 143, 'only': 144, 'slight': 145, 'risk': 146, 'Spanish': 147, 'Minister': 148, 'Loyola': 149, 'de': 150, 'Palacio': 151, 'had': 152, 'earlier': 153, 'accused': 154, 'at': 155, 'an': 156, 'farm': 157, 'ministers': 158, "'": 159, 'meeting': 160, 'of': 161, 'causing': 162, 'unjustified': 163, 'alarm': 164, 'through': 165, 'dangerous': 166, 'generalisation': 167, 'Only': 168, 'backed': 169, 'multidisciplinary': 170, 'committees': 171, 'are': 172, 'due': 173, 're-examine': 174, 'issue': 175, 'early': 176, 'next': 177, 'make': 178, 'recommendations': 179, 'senior': 180, 'Sheep': 181, 'have': 182, 'long': 183, 'been': 184, 'known': 185, 'scrapie': 186, 'brain-wasting': 187, 'similar': 188, 'which': 189, 'is': 190, 'believed': 191, 'transferred': 192, 'cattle': 193, 'feed': 194, 'containing': 195, 'waste': 196, 'farmers': 197, 'denied': 198, 'danger': 199, 'their': 200, 'but': 201, 'expressed': 202, 'concern': 203, 'government': 204, 'avoid': 205, 'might': 206, 'influence': 207, 'across': 208, 'Europe': 209, 'What': 210, 'extremely': 211, 'careful': 212, 'how': 213, 'going': 214, 'take': 215, 'lead': 216, 'Welsh': 217, 'National': 218, 'Farmers': 219, 'NFU': 220, 'chairman': 221, 'John': 222, 'Lloyd': 223, 'Jones': 224, 'BBC': 225, 'radio': 226, 'Bonn': 227, 'has': 228, 'led': 229, 'efforts': 230, 'public': 231, 'consumer': 232, 'confidence': 233, 'collapsed': 234, 'in': 235, 'March': 236, 'report': 237, 'suggested': 238, 'humans': 239, 'illness': 240, 'eating': 241, 'contaminated': 242, 'beef': 243, 'imported': 244, '47,600': 245, 'year': 246, 'nearly': 247, 'half': 248, 'total': 249, 'imports': 250, 'It': 251, 'brought': 252, '4,275': 253, 'tonnes': 254, 'mutton': 255, 'some': 256, '10': 257, 'percent': 258, 'overall': 259, 'Rare': 260, 'Hendrix': 261, 'song': 262, 'draft': 263, 'sells': 264, 'almost': 265, '$': 266, '17,000': 267, 'LONDON': 268, 'A': 269, 'rare': 270, 'handwritten': 271, 'U.S.': 272, 'guitar': 273, 'legend': 274, 'Jimi': 275, 'sold': 276, ' ...

# %%
vocab_size = len(word_to_ix)

print(vocab_size)
# Out:
# 30289

# %% [markdown]
# ### **Task 2**:
#
# Implement 3 strategies for loading the embeddings:

# %%
glove_embeddings= {}

with open('data/glove.6B.100d.txt', 'r') as file:
    for line in file:
        elements = line.split(' ')
        word = elements[0]
        word_embedding = np.array([float(val) for val in elements[1:]])
        glove_embeddings[word] = word_embedding

# %%
embedding_length=len(glove_embeddings['the'])
print("Embedding vector length: ", embedding_length)
# Out:
# Embedding vector length:  100

# %% [markdown]
# **(a):** load the embeddings for original capitalization of words. If embedding for this word doesn’t exists, associate it with UNKNOWN embedding (5% of score).

# %%
embeddings_matrix_a = np.zeros((vocab_size, 100))
unknown_a=0
for word, ix in word_to_ix.items():
    try:
        embeddings_matrix_a[ix, :] = glove_embeddings[word]
    except KeyError as e:
        embeddings_matrix_a[ix, :] = glove_embeddings['unknown']
        unknown_a+=1

# %%
print("Number of unknown: ", unknown_a )
# Out:
# Number of unknown:  15671

# %% [markdown]
# **(b).** load the embeddings for lowercased capitalization of words. If embedding for this lowercased word doesn’t exists, associate it with UNKNOWN embedding (5% of score).

# %%
embeddings_matrix_b = np.zeros((vocab_size, 100))
unknown_b=0
for word, ix in word_to_ix.items():
    try:
        embeddings_matrix_b[ix, :] = glove_embeddings[word.lower()]
    except KeyError as e:
        embeddings_matrix_b[ix, :] = glove_embeddings['unknown']
        unknown_b+=1

# %%
print("Number of unknown: ", unknown_b)
# Out:
# Number of unknown:  3949

# %% [markdown]
# **(c).** load the embeddings for original capitalization of words. If embedding for this word doesn’t exists, try to find the embedding for lowercased version and associate it to the word with original capitalization. Otherwise, associate it with UNKNOWN embedding(20% of score).

# %%
embeddings_matrix_c = np.zeros((vocab_size, 100))
unknown_c=0
for word, ix in word_to_ix.items():
    if word in glove_embeddings:
        embeddings_matrix_c[ix, :] = glove_embeddings[word]
    elif word.lower() in glove_embeddings:
        embeddings_matrix_c[ix, :] = glove_embeddings[word.lower()]
    else:
        embeddings_matrix_c[ix, :] = glove_embeddings['unknown']
        unknown_c+=1

# %%
print("Number of unknown: ", unknown_c)
# Out:
# Number of unknown:  3949

# %% [markdown]
# ### **Task 2**:
#
# Implement training on batches (20% of score).

# %%
EMBEDDING_DIM = embedding_length
HIDDEN_DIM = 50
EMBEDDING_MATRIX=embeddings_matrix_c
VOCAB_SIZE=EMBEDDING_MATRIX.shape[0]
TARGET_SIZE=len(tag_to_ix)

# %%
training_data = []
dev_data = []
test_data = []
train_grouped = train.groupby(['sentence']).agg(lambda x: list(x)).reset_index(drop=True)
for i in range(len(train_grouped)):
    training_data.append((train_grouped.loc[i, 'word'], train_grouped.loc[i, 'NE_tag']))
dev_grouped = dev.groupby(['sentence']).agg(lambda x: list(x)).reset_index(drop=True)
for i in range(len(dev_grouped)):
    dev_data.append((dev_grouped.loc[i, 'word'], dev_grouped.loc[i, 'NE_tag']))
test_grouped = test.groupby(['sentence']).agg(lambda x: list(x)).reset_index(drop=True)
for i in range(len(test_grouped)):
    test_data.append((test_grouped.loc[i, 'word'], test_grouped.loc[i, 'NE_tag']))

# %%
training_data [0]
# Out:
# (['EU', 'rejects', 'German', 'call', 'to', 'boycott', 'British', 'lamb', '.'],
#  ['B-ORG', 'O', 'B-MISC', 'O', 'O', 'O', 'B-MISC', 'O', 'O'])

# %%
class LSTMTagger(nn.Module):

    def __init__(self,embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim
        
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim).from_pretrained(
        torch.tensor(EMBEDDING_MATRIX, dtype=torch.float))
        self.word_embeddings.weight.requires_grad = False
        
        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
        tag_space = self.hidden2tag(lstm_out.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_space, dim=1)
        return tag_scores

# %%
model = LSTMTagger(EMBEDDING_DIM , HIDDEN_DIM, VOCAB_SIZE, TARGET_SIZE)
loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.1)
losses=[]
epochs=[]

print("Start training..............:")
for epoch in range(30): 
    for sentence, tags in training_data:
        # Step 1. Remember that Pytorch accumulates gradients.
        # We need to clear them out before each instance        
        model.zero_grad()

        # Step 2. Get our inputs ready for the network, that is, turn them into
        # Tensors of word indices.
        sentence_in = prepare_sequence(sentence, word_to_ix)
        targets = prepare_sequence(tags, tag_to_ix)

        
        # Step 3. Run our forward pass.
        tag_scores = model(sentence_in)

        # Step 4. Compute the loss, gradients, and update the parameters by
        #  calling optimizer.step()
        loss = loss_function(tag_scores, targets)
        loss.backward()
        optimizer.step()
    losses.append(loss.item())
    epochs.append(epoch)
    print(f'Epoch {epoch} : Loss {loss.item()}')
# Out:
# Start training..............:
# Epoch 0 : Loss 0.15103602409362793
# Epoch 1 : Loss 0.14554905891418457
# Epoch 2 : Loss 0.10618782043457031
# Epoch 3 : Loss 0.09880781173706055
# Epoch 4 : Loss 0.07561063766479492
# Epoch 5 : Loss 0.06079506874084473
# Epoch 6 : Loss 0.052024126052856445
# Epoch 7 : Loss 0.048589468002319336
# Epoch 8 : Loss 0.04235219955444336
# Epoch 9 : Loss 0.03465390205383301
# Epoch 10 : Loss 0.030825138092041016
# Epoch 11 : Loss 0.027204275131225586
# Epoch 12 : Loss 0.0226137638092041
# Epoch 13 : Loss 0.021651268005371094
# Epoch 14 : Loss 0.01965045928955078
# Epoch 15 : Loss 0.01956796646118164
# Epoch 16 : Loss 0.01625514030456543
# Epoch 17 : Loss 0.015863418579101562
# Epoch 18 : Loss 0.013532161712646484
# Epoch 19 : Loss 0.012593746185302734
# Epoch 20 : Loss 0.01140904426574707
# Epoch 21 : Loss 0.009791851043701172
# Epoch 22 : Loss 0.008656024932861328
# Epoch 23 : Loss 0.010126829147338867
# Epoch 24 : Loss 0.010091304779052734
# Epoch 25 : Loss 0.010461091995239258
# Epoch 26 : Loss 0.009008646011352539
# Epoch 27 : Loss 0.012111425399780273
# Epoch 28 : Loss 0.009252309799194336
# Epoch 29 : Loss 0.010833024978637695

# %%
filename = 'data/model30.pkl'
output = open(filename, 'wb')
#pickle.dump(model,output)
with open(filename, 'rb') as pickle_file:
    model_loaded = pickle.load(pickle_file)

# %%
model
# Out:
# LSTMTagger(
#   (word_embeddings): Embedding(30289, 100)
#   (lstm): LSTM(100, 50)
#   (hidden2tag): Linear(in_features=50, out_features=9, bias=True)
# )

# %%
model_loaded
# Out:
# LSTMTagger(
#   (word_embeddings): Embedding(30289, 100)
#   (lstm): LSTM(100, 50)
#   (hidden2tag): Linear(in_features=50, out_features=9, bias=True)
# )

# %%
with torch.no_grad():
    inputs = prepare_sequence(dev_data[120][0], word_to_ix)
    tag_scores = model(inputs)
tag_scores
# Out:
# tensor([[-1.0831e+01, -1.2034e+01, -6.8271e+00, -1.1282e-03, -2.0422e+01,
#          -1.9767e+01, -1.7008e+01, -1.0912e+01, -1.7414e+01],
#         [-2.1461e+01, -1.9454e+01, -1.5933e+01, -1.5259e+01, -9.6717e+00,
#          -1.2609e+01, -8.8447e+00, -1.6713e+00, -2.0852e-01],
#         [-1.6192e+01, -1.4071e+01, -1.6699e+01, -1.2927e+01, -1.5037e+01,
#          -1.9383e+01, -1.2311e+01, -1.1517e+01, -1.8120e-05],
#         [-1.0159e+01, -6.4259e+00, -7.6228e+00, -5.6080e+00, -1.7043e+01,
#          -1.8085e+01, -1.6861e+01, -1.2285e+01, -5.8374e-03],
#         [-1.8133e+01, -1.8992e+01, -1.9773e+01, -2.1643e+01, -1.9085e+01,
#          -1.5303e+01, -1.8362e+01, -1.7667e+01,  0.0000e+00],
#         [-1.5455e+01, -1.8560e+01, -2.1529e+01, -2.2534e+01, -2.4147e+01,
#          -2.6264e+01, -2.8178e+01, -3.1964e+01,  0.0000e+00],
#         [-2.0627e+01, -1.4935e+01, -2.1152e+01, -2.5505e+01, -2.9034e+01,
#          -2.6578e+01, -3.2355e+01, -3.3287e+01,  0.0000e+00],
#         [-1.9955e+01, -1.7779e+01, -2.4771e+01, -2.2295e+01, -2.3699e+01,
#          -2.5207e+01, -2.2971e+01, -2.8308e+01,  0.0000e+00],
#         [-2.5214e+01, -2.6169e+01, -2.4748e+01, -2.1104e+01, -2.5296e+01,
#          -2.3523e+01, -2.6094e+01, -2.6642e+01,  0.0000e+00],
#         [-4.7503e+00, -9.9799e+00, -6.1480e+00, -7.1109e+00, -2.3451e+01,
#          -2.0806e+01, -2.0921e+01, -1.9971e+01, -1.1718e-02],
#         [-2.0931e+01, -1.3584e+01, -1.7388e+01, -1.9297e+01, -1.9197e+01,
#          -1.5928e+01, -2.0904e+01, -1.5947e+01, -1.9073e-06],
#         [-1.8041e+01, -1.5871e+01, -1.9217e+01, -1.9991e+01, -3.7025e+01,
#          -2.4237e+01, -3.2021e+01, -3.0898e+01,  0.0000e+00],
#         [-2.0811e+01, -2.4569e+01, -2.6549e+01, -3.2432e+01, -2.7648e+01,
#          -3.2396e+01, -3.4458e+01, -3.5827e+01,  0.0000e+00],
#         [-1.2654e+01, -1.3521e+01, -1.5935e+01, -2.1017e+01, -2.5031e+01,
#          -2.5065e+01, -2.9503e+01, -2.8781e+01, -3.8147e-06],
#         [-9.8796e+00, -1.1511e+01, -1.3620e+01, -1.6313e+01, -2.0845e+01,
#          -1.8843e+01, -2.3859e+01, -2.6405e+01, -6.2943e-05],
#         [-9.9845e+00, -9.2580e+00, -1.3080e+01, -1.0022e+01, -1.1676e+01,
#          -9.5689e+00, -1.6983e+01, -1.5892e+01, -2.6608e-04],
#         [-2.2831e+01, -2.1360e+01, -2.1510e+01, -1.7120e+01, -2.3295e+01,
#          -1.6982e+01, -2.5912e+01, -2.0329e+01,  0.0000e+00],
#         [-1.3876e+01, -1.2435e+01, -1.3651e+01, -1.4104e+01, -2.7483e+01,
#          -1.8493e+01, -2.5229e+01, -2.1808e+01, -7.6294e-06],
#         [-1.7703e+01, -1.8111e+01, -1.9011e+01, -1.5761e+01, -3.0069e+01,
#          -2.4895e+01, -2.6984e+01, -2.4539e+01,  0.0000e+00],
#         [-1.5036e+01, -1.2755e+01, -1.7192e+01, -1.3695e+01, -2.8844e+01,
#          -2.3582e+01, -2.9439e+01, -2.1915e+01, -3.8147e-06],
#         [-1.5597e+01, -1.1906e+01, -1.4876e+01, -9.1540e+00, -2.8926e+01,
#          -2.3311e+01, -3.0877e+01, -2.4952e+01, -1.1253e-04],
#         [-1.8661e+01, -1.4391e+01, -1.8350e+01, -2.1839e+01, -2.4403e+01,
#          -1.7374e+01, -2.0217e+01, -2.4181e+01,  0.0000e+00],
#         [-1.3006e+00, -4.6446e-01, -2.3129e+00, -8.6644e+00, -1.6663e+01,
#          -2.0598e+01, -1.5802e+01, -1.5230e+01, -1.0905e+01],
#         [-1.6934e+00, -4.1936e+00, -1.4353e+00, -7.0463e+00, -1.9460e+00,
#          -4.8420e+00, -1.4552e+00, -1.7261e+00, -1.0328e+01],
#         [-1.6409e+01, -1.9254e+01, -1.2588e+01, -1.6743e+01, -1.6064e+01,
#          -1.2222e+01, -1.3282e+01, -1.5928e+01, -1.0490e-05],
#         [-1.2552e+01, -6.5678e+00, -4.7820e+00, -9.8391e-03, -2.0978e+01,
#          -1.6925e+01, -1.7646e+01, -1.3414e+01, -1.3592e+01],
#         [-1.6775e+01, -9.2937e+00, -1.4459e+01, -7.1299e+00, -8.5109e+00,
#          -4.7640e+00, -7.7579e+00, -1.9869e-02, -4.6440e+00],
#         [-1.2446e+01, -3.7748e+00, -1.1647e+01, -5.4569e+00, -8.4015e+00,
#          -2.7249e+00, -1.2654e+01, -1.6544e-01, -2.8221e+00],
#         [-2.2641e+01, -1.2091e+01, -1.9978e+01, -1.4298e+01, -1.1841e+01,
#          -3.8170e+00, -1.8105e+01, -9.4328e+00, -2.2335e-02],
#         [-1.0422e+01, -2.1230e+00, -8.3258e+00, -1.5071e-01, -8.2156e+00,
#          -4.9689e+00, -1.6162e+01, -4.3832e+00, -8.3076e+00],
#         [-1.8874e+01, -1.3839e+01, -1.5687e+01, -1.4202e+01, -7.9367e+00,
#          -1.4394e+00, -1.1014e+01, -5.6536e+00, -2.7568e-01]])

# %%
prepare_sequence(dev_data[120][1], tag_to_ix)
# Out:
# tensor([3, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 4,
#         8, 3, 7, 7, 7, 7, 8])

# %%
tag_scores.numpy().argmax(axis=1)
# Out:
# array([3, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8,
#        1, 2, 8, 3, 7, 7, 8, 3, 8])
